# %%
import pandas as pd
df = pd.read_csv('results/database_result.csv', delimiter=',')

# %%
df.head()
# Out:
#             zinc_id                                             smiles  \
# 0  ZINC000032011198  C[N+]1(CC2CCCCCC2)CCC(NC(=O)C2c3cc(Cl)ccc3Oc3c...
# 1  ZINC000000057109                               COc1ccc(C=O)c(Br)c1O
# 2  ZINC000004353694  OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)c1nc2cc(C...
# 3  ZINC000004352937                                 CC(C)CN(CC(C)C)N=O
# 4  ZINC000003171687  CC(C)c1ccc2c(c1)CC[C@H]1[C@](C)(C(N)=O)CCC[C@@...
#
#    Predictive Results
# 0            5.318430
# 1            5.423908
# 2            5.976683
# 3            5.000304
# 4            5.495298

# %%
len(df)
# Out:
# 306347

# %%
from operator import index

df2 = df.sort_values(by=["Predictive Results"],ascending=False)

# %%
df3 = df2.head(5).drop_duplicates()

# %%
df3
# Out:
#                  zinc_id                                             smiles  \
# 24235   ZINC000119208393  C=C1CC[C@]2(OC1)O[C@@H]1C[C@H]3[C@@H]4CC[C@H]5...
# 30486   ZINC000118930108  C=C(C)[C@H]1CC[C@@]2(CO)[C@@H](O)C[C@@]3(C)[C@...
# 40443   ZINC000100784071  CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@@H](O)CC...
# 30315   ZINC000100784072  CCCCCCCCCCCC[C@H](O)[C@H]1CC[C@H]([C@@H](O)CC[...
# 242062  ZINC000257516500  CCCCCCCCC[C@H](O)CCCC[C@H](O)[C@H](O)CC[C@H](O...
#
#         Predictive Results
# 24235             6.777573
# 30486             6.765462
# 40443             6.728593
# 30315             6.716955
# 242062            6.706481

# %%
smiles_list = df3["smiles"].to_list()
smiles_list
# Out:
# ['C=C1CC[C@]2(OC1)O[C@@H]1C[C@H]3[C@@H]4CC[C@H]5C[C@@H](O)C[C@@H](O)[C@]5(C)[C@H]4CC[C@]3(C)[C@H]1[C@@H]2C',
#  'C=C(C)[C@H]1CC[C@@]2(CO)[C@@H](O)C[C@@]3(C)[C@@H](CC[C@H]4[C@]5(C)CC[C@H](O)C(C)(C)[C@@H]5CC[C@@]43C)[C@H]12',
#  'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@@H](O)CC[C@@H](O)C[C@@H](O)C[C@@H](O)CCC[C@@H](O)CC2=C[C@@H](C)OC2=O)O1',
#  'CCCCCCCCCCCC[C@H](O)[C@H]1CC[C@H]([C@@H](O)CC[C@@H](O)C[C@@H](O)C[C@@H](O)CCC[C@@H](O)CC2=C[C@@H](C)OC2=O)O1',
#  'CCCCCCCCC[C@H](O)CCCC[C@H](O)[C@H](O)CC[C@H](O)[C@@H]1CC[C@H](CCCCC[C@@H](O)CC2=C[C@@H](C)OC2=O)O1']

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
import mols2grid
from rdkit.Chem import Draw

# %%
mols = []
for i in smiles_list:
  mols.append(Chem.MolFromSmiles(i))

# %%
df3["rdkit_object"]= mols

# %%
mols2grid.display(df3,mol_col='rdkit_object',subset=["img",'Predictive Results'])
# Out:
# MolGridWidget()
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# #mols2grid .data {
#     overflow: hidden;
#     white-space: nowrap;
# ...
